# %%
from automatic_athena_download import *
import pandas as pd

# %%
df=pd.DataFrame()
query="SELECT * FROM processed_customers WHERE customer_state = 'SP';"
df=traer_df(query)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# c:\Users\Cecilia\Documents\TP\TP_Grupal_Olist\prueba.ipynb Celda 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Cecilia/Documents/TP/TP_Grupal_Olist/prueba.ipynb#ch0000001?line=0'>1</a> df=pd.DataFrame()
#       <a href='vscode-notebook-cell:/c%3A/Users/Cecilia/Documents/TP/TP_Grupal_Olist/prueba.ipynb#ch0000001?line=1'>2</a> query="SELECT * FROM processed_customers WHERE customer_state = 'SP';"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Cecilia/Documents/TP/TP_Grupal_Olist/prueba.ipynb#ch0000001?line=2'>3</a> df=traer_df(query)
#
# File c:\Users\Cecilia\Documents\TP\TP_Grupal_Olist\automatic_athena_download.py:66, in traer_df(myquery)
#      63 def traer_df(myquery):
#      64     # Query Athena and get the s3 filename as a result
#      65     params.update({'query': myquery})
# ...

# %%
df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 41741  f255d679c7c86c24ef4861320d5b7675  d111b06b6f3a2add0d2241325f65b5ca
# 41742  f5a0b560f9e9427792a88bec97710212  b3e53d18a997f27a3ffd16da497eaf58
# 41743  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 41744  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 41745  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...
